# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x1=pd.read_csv('Winner.csv')

# %%
x2=x1.drop('Support(avg)',axis=1)

# %%
ax=x2.plot.barh(x=x1['Class'],figsize=(12,12))
ax.set_xlabel("F1_score")
# Out:
# Text(0.5,0,'F1_score')
